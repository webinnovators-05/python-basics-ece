# %%
# step-1: we have to import the dataset to the colab notebook.
import pandas as pd # pd is  an instance of pandas
df = pd.read_csv("Data.csv") # df is a variable, read_csv is a predifined funtion from pandas package

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#step-2: grouping the input columns and output columns
X=df.iloc[:,:-1]

# %%
X
# Out:
#    Country   Age   Salary
# 0   France  44.0  72000.0
# 1    Spain  27.0  48000.0
# 2  Germany  30.0  54000.0
# 3    Spain  38.0  61000.0
# 4  Germany  40.0      NaN
# 5   France  35.0  58000.0
# 6    Spain   NaN  52000.0
# 7   France  48.0  79000.0
# 8  Germany  50.0  83000.0
# 9   France  37.0  67000.0

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8     No
# 9    Yes
# Name: Purchased, dtype: object

# %%
X=X.values

# %%
X
# Out:
# array([['France', 44.0, 72000.0],
#        ['Spain', 27.0, 48000.0],
#        ['Germany', 30.0, 54000.0],
#        ['Spain', 38.0, 61000.0],
#        ['Germany', 40.0, nan],
#        ['France', 35.0, 58000.0],
#        ['Spain', nan, 52000.0],
#        ['France', 48.0, 79000.0],
#        ['Germany', 50.0, 83000.0],
#        ['France', 37.0, 67000.0]], dtype=object)

# %%
y
# Out:
# 0     No
# 1    Yes
# 2     No
# 3     No
# 4    Yes
# 5    Yes
# 6     No
# 7    Yes
# 8     No
# 9    Yes
# Name: Purchased, dtype: object

# %%
#step-3:Handling missing data and NaN
#scenario-1:
#scenario-2:
#scenario-3:

import numpy as np
from sklearn.impute import SimpleImputer
Imputer=SimpleImputer(missing_values=np.nan,strategy='mean')
Imputer.fit(X[:,1:3])
X[:,1:3]=Imputer.transform(X[:,1:3])

# %%
#Step-4 handling catogorial data
# which converts the text data into numeric data.
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

#Alexa-0,0,1

ct=ColumnTransformer(transformers=[('encoder',OneHotEncoder(),[0])],remainder='passthrough')#Encoder is a method which converts text to numeric
X=ct.fit_transform(X)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
y=le.fit_transform(y)

# %%
# Step-5: Split the data into training and testing data
from sklearn.model_selection import train_test_split #
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train
# Out:
# array([[1.0, 0.0, 0.0, 37.0, 67000.0],
#        [1.0, 0.0, 0.0, 35.0, 58000.0],
#        [0.0, 1.0, 0.0, 30.0, 54000.0],
#        [0.0, 1.0, 0.0, 50.0, 83000.0],
#        [0.0, 1.0, 0.0, 40.0, 63777.77777777778],
#        [1.0, 0.0, 0.0, 44.0, 72000.0],
#        [0.0, 0.0, 1.0, 27.0, 48000.0],
#        [0.0, 0.0, 1.0, 38.77777777777778, 52000.0]], dtype=object)

# %%
X_test
# Out:
# array([[1.0, 0.0, 0.0, 48.0, 79000.0],
#        [0.0, 0.0, 1.0, 38.0, 61000.0]], dtype=object)

# %%
y_train
# Out:
# array([1, 1, 0, 0, 1, 0, 1, 0])

# %%
y_test
# Out:
# array([1, 0])

# %%
#step-6:feature scaling
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train[:,3:]=sc.fit_transform(X_train[:,3:])
X_test[:,3:]=sc.transform(X_test[:,3:])

# %%
X_train
# Out:
# array([[1.0, 0.0, 0.0, -0.10493087859486074, 0.43965188786731324],
#        [1.0, 0.0, 0.0, -0.39550869624216767, -0.3885295753246018],
#        [0.0, 1.0, 0.0, -1.121953240360435, -0.7566102256321197],
#        [0.0, 1.0, 0.0, 1.7838249361126344, 1.9119744890973844],
#        [0.0, 1.0, 0.0, 0.3309358478760997, 0.14314247511959086],
#        [1.0, 0.0, 0.0, 0.9120914831707136, 0.8997527007517104],
#        [0.0, 0.0, 1.0, -1.5578199668313955, -1.3087312010933962],
#        [0.0, 0.0, 1.0, 0.15336051486941224, -0.9406505507858784]],
#       dtype=object)

# %%
X_test
# Out:
# array([[1.0, 0.0, 0.0, 1.4932471184653275, 1.5438938387898666],
#        [0.0, 0.0, 1.0, 0.040358030228792745, -0.11246908759396347]],
#       dtype=object)

# %%
 #machine learning
 #1.supervisioned learning -when we have labled data,
 #and the model tasks are classfcation or predicition
 #2.unsupervisioned learning-unlabled data,model remebers the patterns
 #we can perfrom predicition also.
 #3.reinforcement learning-trail, and error method,method learn from

# %%
#logistic regression algorithm=
#linear regression algorithm

# %%
#step-7:applying algorithm to the training data for mo
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=classifier.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0])
